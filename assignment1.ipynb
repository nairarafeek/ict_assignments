# %% [markdown]
# <a href="https://colab.research.google.com/github/nairarafeek/ict_assignments/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
data = pd.read_csv('/content/employee.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 636.0+ bytes

# %%
data = pd.read_csv('/content/employee.csv',index_col='name')

# %%
data.head()
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %%
x = data.drop(['performance_score'], axis=1)
y = data['performance_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=700)

# %%
high_perfomance_employees = data[data['performance_score'] > 700]
print(high_perfomance_employees)
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
performance_score = data[(data['performance_score'] > 500) & (data['performance_score'] < 700)]
print(performance_score)
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %%
data.isna().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
sns.boxplot(data)
plt.show()

# %%
import seaborn as sns
sns.boxplot(data['performance_score'])
plt.show()

# %%
data['gender'].fillna(data['gender'].mode()[0], inplace=True)
print('Missing Value:', data['gender'].isna().sum())
data_encoded = pd.get_dummies(data,columns=['gender'],drop_first=True)
print(data_encoded.head())
# Out:
# Missing Value: 0
#                 age   income  department grade  performance_score  gender_M
# name
# Allen Smith    45.0      NaN  Operations    G3                723     False
# S Kumar         NaN  16000.0     Finance    G0                520     False
# Jack Morgan    32.0  35000.0     Finance    G2                674      True
# Ying Chin      45.0  65000.0       Sales    G3                556     False
# Dheeraj Patel  30.0  42000.0  Operations    G2                711     False
# /tmp/ipykernel_6561/1926629214.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
