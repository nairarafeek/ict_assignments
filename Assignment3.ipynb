# %% [markdown]
# <a href="https://colab.research.google.com/github/nairarafeek/ict_assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1

# %%
max(55,66,77)
# Out:
# 77

# %% [markdown]
# 2

# %%
def sum_list(numbers):
  total = 0
  for number in numbers:
    total += number
  return total
sample_list = [18, 12, 30, 10, 7]
result = sum_list(sample_list)
print("The sum of the list is:", result)
# Out:
# The sum of the list is: 77

# %% [markdown]
# 3

# %%
mylist = [1, 2, 3, 4, 5]
number_to_insert = 6
index_to_insert = 2
mylist.insert(index_to_insert, number_to_insert)
print(mylist)
# Out:
# [1, 2, 6, 3, 4, 5]

# %% [markdown]
# 4

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
sample_dict['location'] = sample_dict.pop('city')
print(sample_dict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# **5**

# %%
sample_dict = {'emp1': {'name': 'Jhon', 'salary': 7500},
 'emp2': {'name': 'Emma', 'salary': 8000},
 'emp3': {'name': 'Brad', 'salary': 500}}
sample_dict['emp3']['salary'] = 8500
print(sample_dict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# **6**

# %%
tuple1=(11,22,33,44,55,66)
tuple=tuple1[3:5]
print(tuple)
# Out:
# (44, 55)

# %% [markdown]
# **7**

# %%
tuple1=(50,10,60,70,50,83,567,50,81)
tuple=50
occurrences = tuple1.count(tuple)
print(occurrences)
# Out:
# 3
