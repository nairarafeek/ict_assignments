# %% [markdown]
# <a href="https://colab.research.google.com/github/nairarafeek/ict_assignments/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1**

# %%
def add_book():
    while True:
        book_id = input("Enter Book ID (e.g., B001): ").strip().upper()
        if not book_id:
            print("Book ID cannot be empty. Please try again.")
            continue
        if book_id in books:
            print(f"Book with ID '{book_id}' already exists. Please enter a unique ID.")
        else:
            break

    title = input("Enter Title: ").strip()
    while not title:
        print("Title cannot be empty. Please try again.")
        title = input("Enter Title: ").strip()

    author = input("Enter Author: ").strip()
    while not author:
        print("Author cannot be empty. Please try again.")
        author = input("Enter Author: ").strip()

    while True:
        try:
            total_copies = int(input("Enter Total Copies: "))
            if total_copies <= 0:
                print("Total copies must be a positive integer. Please try again.")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a number for total copies.")

    books[book_id] = {
        'book_id': book_id,
        'title':title,
        'author':author,
        'total_copies':total_copies,
        'avoilable_copies':total_copies
    }
    print(f"book '{title}' added")

# %% [markdown]
# **3**
