# %% [markdown]
# <a href="https://colab.research.google.com/github/nairarafeek/ict_assignments/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
'/content/athlete_events - medal (1).csv'
# Out:
# '/content/athlete_events - medal (1).csv'

# %%
auto_data = pd.read_csv('/content/athlete_events - medal (1).csv')
auto_data
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 0            1                     A Dijiang   M  24.0   180.0    80.0
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 2            3           Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4          Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5      Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                           ...  ..   ...     ...     ...
# 246859  123601  Nataliya Andreyevna Ustinova   F  19.0   165.0    58.0
# 246860  123601  Nataliya Andreyevna Ustinova   F  23.0   165.0    58.0
# 246861  123601  Nataliya Andreyevna Ustinova   F  23.0   165.0    58.0
# 246862  123602  Tetiana Illivna Ustiuzhanina   F  27.0   185.0    78.0
# 246863  123602  Tetiana Illivna Ustiuzhanina   F  31.0   185.0    78.0
#
#                   Team  NOC        Games    Year  Season         City  \
# ...

# %% [markdown]
# ## **1**

# %%
auto_data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games    Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992.0  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012.0  Summer     London           Judo
# 2  DEN  1920 Summer  1920.0  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900.0  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988.0  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
auto_data.shape
# Out:
# (246864, 15)

# %%
auto_data[auto_data['Name']=='?']
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
auto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246864 entries, 0 to 246863
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      246864 non-null  int64
#  1   Name    246864 non-null  object
#  2   Sex     246864 non-null  object
#  3   Age     238197 non-null  float64
#  4   Height  192051 non-null  float64
#  5   Weight  189517 non-null  float64
#  6   Team    246864 non-null  object
#  7   NOC     246864 non-null  object
#  8   Games   246864 non-null  object
#  9   Year    246863 non-null  float64
#  10  Season  246863 non-null  object
#  11  City    246863 non-null  object
#  12  Sport   246863 non-null  object
#  13  Event   246863 non-null  object
#  14  Medal   35956 non-null   object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 28.3+ MB

# %% [markdown]
# ### **2**

# %%
auto_data.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year      float64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
numerical_cols = data.dtypes[data.dtypes != 'object'].index
categorical_cols = data.dtypes[data.dtypes == 'object'].index

numerical_cols, categorical_cols
# Out:
# (Index(['ID', 'Age', 'Height', 'Weight', 'Year'], dtype='object'),
#  Index(['Name', 'Sex', 'Team', 'NOC', 'Games', 'Season', 'City', 'Sport',
#         'Event', 'Medal'],
#        dtype='object'))

# %% [markdown]
# ### **3**

# %%
missing_values = data.isna().sum()
missing_values
# Out:
# ID             0
# Name           0
# Sex            0
# Age         8667
# Height     54813
# Weight     57347
# Team           0
# NOC            0
# Games          0
# Year           1
# Season         1
# City           1
# Sport          1
# Event          1
# Medal     210908
# dtype: int64

# %%
auto_data['Medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %% [markdown]
# ### **4**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
medal_winners.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games    Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900.0  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920.0  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920.0  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014.0  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948.0  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# ...

# %% [markdown]
# ## **5**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
total_medals_by_country = medal_winners['Team'].value_counts()
total_medals_by_country.head(10)
# Out:
# Team
# United States    4793
# Soviet Union     2226
# Germany          1723
# Great Britain    1545
# France           1497
# Italy            1425
# Sweden           1342
# Australia        1205
# Canada           1140
# Hungary          1040
# Name: count, dtype: int64

# %% [markdown]
# # **6**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
medal_winners = data.loc[data['Medal'] == data['Medal']]
total_medals_by_country = medal_winners['Team'].value_counts().head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=total_medals_by_country.values, y=total_medals_by_country.index, palette="viridis")
plt.title("Top 10 Countries by Total Olympic Medals", fontsize=16)
plt.xlabel("Number of Medals", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_392/3036172702.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_medals_by_country.values, y=total_medals_by_country.index, palette="viridis")

# %% [markdown]
# # **7**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
gold_medals = medal_winners[medal_winners['Medal'] == 'Gold']
gold_medals.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games    Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900.0  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992.0  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
top_gold_countries = gold_medals['Team'].value_counts().head(10)
top_gold_countries
# Out:
# Team
# United States    2264
# Soviet Union      965
# Germany           586
# Italy             494
# Great Britain     477
# France            442
# Sweden            416
# Hungary           402
# Canada            391
# East Germany      329
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=top_gold_countries.values, y=top_gold_countries.index, color="gold")
plt.title("Top 10 Countries by Gold Medals", fontsize=16)
plt.xlabel("Number of Gold Medals", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.show()

# %% [markdown]
# # **8**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
gender_medals = medal_winners['Sex'].value_counts()
gender_medals
# Out:
# Sex
# M    25972
# F     9984
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Sex', data=medal_winners, palette='pastel')
plt.title("Total Medals by Gender", fontsize=16)
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Number of Medals", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_392/2477455565.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=medal_winners, palette='pastel')

# %% [markdown]
# # **9**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
gender_trend = medal_winners.groupby(['Year', 'Sex'])['Medal'].count().reset_index()
gender_trend = gender_trend.rename(columns={'Medal': 'Medal_Count'})
gender_trend.head()
# Out:
#      Year Sex  Medal_Count
# 0  1896.0   M          129
# 1  1900.0   F           12
# 2  1900.0   M          543
# 3  1904.0   F            9
# 4  1904.0   M          422

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=gender_trend, x='Year', y='Medal_Count', hue='Sex', marker='o')
plt.title("Olympic Medal Trend Over Years by Gender", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Medals", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # **10**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
top_sports = medal_winners['Sport'].value_counts().head(10)
top_sports
# Out:
# Sport
# Athletics     3654
# Swimming      2717
# Rowing        2683
# Gymnastics    2049
# Fencing       1599
# Football      1439
# Ice Hockey    1414
# Hockey        1366
# Wrestling     1178
# Cycling       1131
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=top_sports.values, y=top_sports.index, palette="coolwarm")
plt.title("Top 10 Sports by Total Medals", fontsize=16)
plt.xlabel("Number of Medals", fontsize=12)
plt.ylabel("Sport", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_392/1165448740.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_sports.values, y=top_sports.index, palette="coolwarm")

# %% [markdown]
# # **11**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
gold_medals = medal_winners[medal_winners['Medal'] == 'Gold']

# %%
gold_medals_by_sport = gold_medals['Sport'].value_counts()
top_gold_sport = gold_medals_by_sport.idxmax()
top_gold_count = gold_medals_by_sport.max()
top_gold_sport, top_gold_count
# Out:
# ('Athletics', 1230)

# %% [markdown]
# # **12**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
medals_per_year = medal_winners.groupby('Year')['Medal'].count().reset_index()
medals_per_year = medals_per_year.rename(columns={'Medal': 'Total_Medals'})
medals_per_year.head()
# Out:
#      Year  Total_Medals
# 0  1896.0           129
# 1  1900.0           555
# 2  1904.0           431
# 3  1906.0           420
# 4  1908.0           764

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=medals_per_year, x='Year', y='Total_Medals', marker='o')
plt.title("Olympic Medal Trend Over Time", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Medals", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # **13**

# %%
best_year = medals_per_year.loc[medals_per_year['Total_Medals'].idxmax()]
best_year
# Out:
# Year            1992.0
# Total_Medals    1831.0
# Name: 22, dtype: float64

# %% [markdown]
# # **14**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']]
ages = medal_winners['Age'].dropna()

# %%
plt.figure(figsize=(12,6))
sns.histplot(ages, bins=30, kde=True, color='skyblue')
plt.title("Age Distribution of Olympic Medal Winners", fontsize=16)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Number of Medal Winners", fontsize=12)
plt.grid(True)
plt.show()

# %%
most_common_age_range = age_range_counts.idxmax()
most_common_age_count = age_range_counts.max()
most_common_age_range, most_common_age_count
# Out:
# ('21-25', 14115)

# %% [markdown]
# # **15**

# %%
medal_winners = data.loc[data['Medal'] == data['Medal']].dropna(subset=['Age'])

# %%
average_age_by_medal = medal_winners.groupby('Medal')['Age'].mean()
average_age_by_medal
# Out:
# Medal
# Bronze    25.902074
# Gold      25.906690
# Silver    26.027022
# Name: Age, dtype: float64

# %% [markdown]
# # **16**

# %%
numerical_cols = medal_winners[['Age', 'Height', 'Weight']].dropna()
correlation_matrix = numerical_cols.corr()
sns.heatmap(correlation_matrix, annot=True,  fmt='.2f')
plt.title('Correlation Heatmap of Age, Height, and Weight ')
plt.show()

# %% [markdown]
# # **17**

# %%
country_noc = input("Enter the NOC code of the country (e.g., USA, GBR): ")

# Create a DataFrame with total medals per country, including NOC
# This assumes 'medal_winners' is already defined, which it is from previous cells.
total_medals_per_country = medal_winners.groupby(['NOC', 'Team'])['Medal'].count().reset_index()
total_medals_per_country = total_medals_per_country.rename(columns={'Medal': 'Total_Medals'})


selected_country_medals = total_medals_per_country[total_medals_per_country['NOC'] == country_noc.upper()]

if not selected_country_medals.empty:
    display(selected_country_medals)
else:
    print(f"No data found for country with NOC code: {country_noc.upper()}")
# Out:
# Enter the NOC code of the country (e.g., USA, GBR): 2
# No data found for country with NOC code: 2

# %%
gold_medals_per_country = gold_medals.groupby(['NOC', 'Team'])['Medal'].count().reset_index()
gold_medals_per_country = gold_medals_per_country.rename(columns={'Medal': 'Total_Gold_Medals'})
display(gold_medals_per_country.head(10))
# Out:
#    NOC                          Team  Total_Gold_Medals
# 0  ALG                       Algeria                  5
# 1  ANZ                   Australasia                 20
# 2  ARG                     Argentina                 85
# 3  ARM                       Armenia                  2
# 4  AUS  Amateur Athletic Association                  1
# 5  AUS                     Australia                320
# 6  AUS                   Australia-1                  2
# 7  AUS                    Barrenjoey                  3
# 8  AUT                       Austria                 89
# 9  AUT                     Austria-1                 11

# %%
print(f"The sport with the highest number of Gold medals is: {top_gold_sport} with {top_gold_count} Gold Medals.")
# Out:
# The sport with the highest number of Gold medals is: Athletics with 1230 Gold Medals.

# %%
display(medals_per_year.head())
# Out:
#      Year  Total_Medals
# 0  1896.0           129
# 1  1900.0           555
# 2  1904.0           431
# 3  1906.0           420
# 4  1908.0           764

# %% [markdown]
# # **18**

# %%
display(total_medals_per_country.head())
# Out:
#    NOC                  Team  Total_Medals
# 0  AFG           Afghanistan             2
# 1  AHO  Netherlands Antilles             1
# 2  ALG               Algeria            16
# 3  ANZ           Australasia            27
# 4  ARG             Argentina           252

# %%
display(gender_trend.head())
# Out:
#      Year Sex  Medal_Count
# 0  1896.0   M          129
# 1  1900.0   F           12
# 2  1900.0   M          543
# 3  1904.0   F            9
# 4  1904.0   M          422

# %%
display(average_age_by_medal)
# Out:
# Medal
# Bronze    25.902074
# Gold      25.906690
# Silver    26.027022
# Name: Age, dtype: float64
